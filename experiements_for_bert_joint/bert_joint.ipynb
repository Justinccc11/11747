# %%
# !git clone https://github.com/google-research/language.git
# Out:
# Cloning into 'language'...
# remote: Enumerating objects: 1957, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 1957 (delta 29), reused 90 (delta 22), pack-reused 1856
# Receiving objects: 100% (1957/1957), 2.18 MiB | 12.13 MiB/s, done.
# Resolving deltas: 100% (1125/1125), done.

# %%
pip install bert-tensorflow natural-questions
# Out:
# ...
#      |████████████████████████████████| 71kB 3.9MB/s
# ...

# %%
# !gsutil cp -R gs://bert-nq/bert-joint-baseline .
# Out:
# Copying gs://bert-nq/bert-joint-baseline/bert_config.json...
# Copying gs://bert-nq/bert-joint-baseline/bert_joint.ckpt.data-00000-of-00001...
# Copying gs://bert-nq/bert-joint-baseline/bert_joint.ckpt.index...
# Copying gs://bert-nq/bert-joint-baseline/nq-train.tfrecords-00000-of-00001...
# / [4 files][  2.3 GiB/  2.3 GiB]   90.9 MiB/s
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://bert-nq/bert-joint-baseline/vocab-nq.txt...
# / [5 files][  2.3 GiB/  2.3 GiB]   86.5 MiB/s
# Operation completed over 5 objects/2.3 GiB.

# %%
import tensorflow_hub as hub

# %%
cd language
# Out:
# /content/language

# %%
# !ls
# Out:
# bert-joint-baseline  language	  wwm_uncased_L-24_H-1024_A-16
# bert_model_output    sample_data  wwm_uncased_L-24_H-1024_A-16.zip

# %%
# !pip install .
# Out:
# Processing /content/language
# ...
#      |████████████████████████████████| 411.0MB 31kB/s
# ...
#      |████████████████████████████████| 51kB 5.1MB/s
# ...
#      |████████████████████████████████| 512kB 52.3MB/s
# ...
#      |████████████████████████████████| 3.8MB 51.6MB/s
# ...
#      |████████████████████████████████| 20.1MB 178kB/s
# ...
#   Created wheel for language: filename=language-0.0.1.dev0-cp37-none-any.whl size=591121 sha256=098f85ca5bf9ce36ea575e89390af0dbf1cfe373c7aac6a904e87f59886a6525
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a2pof8ex/wheels/c6/ca/64/df882aed2ec820f29eef1558c90ca63cdf0397f0809d26f637
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=0e6d392aa6207f407d6aba46658da2219e2aa3661b31a6778dc8f652589ca3af
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built language gast
# ...

# %%
hub_url_bert = "https://tfhub.dev/tensorflow/uncased_L-24_H-1024_A-16/bert_model.ckpt"
https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/2

# %%
ls
# Out:
# bert-joint-baseline/  language/  sample_data/

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.5

# %%
# !unzip wwm_uncased_L-24_H-1024_A-16.zip
# Out:
# Archive:  wwm_uncased_L-24_H-1024_A-16.zip
#    creating: wwm_uncased_L-24_H-1024_A-16/
#   inflating: wwm_uncased_L-24_H-1024_A-16/bert_model.ckpt.meta
#   inflating: wwm_uncased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001
#   inflating: wwm_uncased_L-24_H-1024_A-16/vocab.txt
#   inflating: wwm_uncased_L-24_H-1024_A-16/bert_model.ckpt.index
#   inflating: wwm_uncased_L-24_H-1024_A-16/bert_config.json

# %%
# !python -m language.question_answering.bert_joint.run_nq \
  --logtostderr \
  --bert_config_file=bert-joint-baseline/bert_config.json \
  --vocab_file=bert-joint-baseline/vocab-nq.txt \
  --train_precomputed_file=bert-joint-baseline/nq-train.tfrecords-00000-of-00001 \
  --train_num_precomputed=494670 \
  --learning_rate=3e-5 \
  --num_train_epochs=5 \
  --max_seq_length=512 \
  --save_checkpoints_steps=5000 \
  --init_checkpoint=bert-joint-baseline/bert_joint.ckpt \
  --do_train \
  --output_dir=bert_model_output_finetune
# Out:
# WARNING:tensorflow:Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f46023a7200>) includes params argument, but params are not passed to Estimator.
# W0413 23:36:17.937022 139941826533248 estimator.py:1994] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f46023a7200>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Using config: {'_model_dir': 'bert_model_output_finetune', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 5000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
# !gsutil cp -R gs://bert-nq/tiny-dev .
# Out:
# Copying gs://bert-nq/tiny-dev/nq-dev-sample.jsonl.gz...
# Copying gs://bert-nq/tiny-dev/nq-dev-sample.no-annot.jsonl.gz...
# - [2 files][ 50.2 MiB/ 50.2 MiB]
# Operation completed over 2 objects/50.2 MiB.

# %%
# !python -m language.question_answering.bert_joint.run_nq \
  --logtostderr \
  --bert_config_file=bert-joint-baseline/bert_config.json \
  --vocab_file=bert-joint-baseline/vocab-nq.txt \
  --predict_file=tiny-dev/nq-dev-sample.no-annot.jsonl.gz \
  --init_checkpoint=bert_model_output_finetune/model.ckpt-0 \
  --do_predict \
  --output_dir=bert_model_output_new \
  --output_prediction_file=bert_model_output_new/predictions.json
# Out:
# WARNING:tensorflow:Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f8a8dfaa200>) includes params argument, but params are not passed to Estimator.
# W0413 23:42:50.173606 140236228540288 estimator.py:1994] Estimator's model_fn (<function model_fn_builder.<locals>.model_fn at 0x7f8a8dfaa200>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Using config: {'_model_dir': 'bert_model_output_new', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
# !python -m natural_questions.nq_eval \
  --logtostderr \
  --gold_path=tiny-dev/nq-dev-sample.jsonl.gz \
  --predictions_path=bert_model_output_new/predictions.json
# Out:
# I0414 00:58:55.295870 139946070546304 eval_utils.py:261] parsing tiny-dev/nq-dev-sample.jsonl.gz .....
# I0414 00:58:59.115898 139946070546304 eval_utils.py:213] Reading predictions from file: bert_model_output_new/predictions.json
# ...
